# %%
import pandas as pd
import csv

def custom_to_csv(data, name):
    data.to_csv(name, index=False)
    f = open(name, "r+")
    lines = f.readlines()
    lines[-1] = lines[-1].rstrip()
    f.close()
    f = open(name, "w+")
    f.writelines(lines)
    f.close()

# %% [markdown]
# <h1>Participants</h1>

# %%
# Read the FinancialJournal CSV file into a DataFrame
finance_df = pd.read_csv("../data/Datasets/Journals/FinancialJournal.csv")
finance_df
# Out:
#          participantId             timestamp    category       amount
# 0                    0  2022-03-01T00:00:00Z        Wage  2472.507559
# 1                    0  2022-03-01T00:00:00Z     Shelter  -554.988622
# 2                    0  2022-03-01T00:00:00Z   Education   -38.005380
# 3                    1  2022-03-01T00:00:00Z        Wage  2046.562206
# 4                    1  2022-03-01T00:00:00Z     Shelter  -554.988622
# ...                ...                   ...         ...          ...
# 1856325             39  2023-05-25T00:05:00Z  Recreation    -2.760368
# 1856326             28  2023-05-25T00:05:00Z  Recreation   -29.458409
# 1856327            370  2023-05-25T00:05:00Z  Recreation   -28.444239
# 1856328            537  2023-05-25T00:05:00Z        Food    -4.000000
# 1856329            362  2023-05-25T00:05:00Z        Food    -4.000000
#
# [1856330 rows x 4 columns]

# %%
# count participants that dropped out after just a month, we know they are 131
count_fin = finance_df["participantId"].value_counts().reset_index().sort_values("count")
dropped_out = count_fin.head(131)
custom_to_csv(dropped_out["participantId"], "DroppedOut.csv")
dropped_out
# Out:
#       participantId  count
# 1010            653     11
# 1009            875     11
# 1008            346     12
# 1004            279     14
# 1007            846     14
# ...             ...    ...
# 882             514     26
# 884             285     26
# 885             621     26
# 881             762     27
# 880             827     29
#
# [131 rows x 2 columns]

# %%
# Take the absolute value of the 'amount' column
finance_df["amount"] = finance_df["amount"].abs()
finance_df.head()
# Out:
#    participantId             timestamp   category       amount
# 0              0  2022-03-01T00:00:00Z       Wage  2472.507559
# 1              0  2022-03-01T00:00:00Z    Shelter   554.988622
# 2              0  2022-03-01T00:00:00Z  Education    38.005380
# 3              1  2022-03-01T00:00:00Z       Wage  2046.562206
# 4              1  2022-03-01T00:00:00Z    Shelter   554.988622

# %%
# Group by 'participantId' and 'category', summing the 'amount' for each group
result_df = finance_df.groupby(["participantId", "category"])["amount"].sum().reset_index()
result_df.head()
# Out:
#    participantId    category         amount
# 0              0   Education     608.086073
# 1              0        Food    3868.580758
# 2              0  Recreation    4870.355051
# 3              0     Shelter    8879.817947
# 4              0        Wage  134904.668457

# %%
# Write the result to a new CSV file
custom_to_csv(result_df, "AggregatedFinancialJournal.csv")

# %% [markdown]
# <hr/>

# %%
# read the participants CSV file into a DataFrame
part_df = pd.read_csv("../data/Datasets/Attributes/Participants.csv")
part_df.head()
# Out:
#    participantId  householdSize  haveKids  age       educationLevel  \
# 0              0              3      True   36  HighSchoolOrCollege
# 1              1              3      True   25  HighSchoolOrCollege
# 2              2              3      True   35  HighSchoolOrCollege
# 3              3              3      True   21  HighSchoolOrCollege
# 4              4              3      True   43            Bachelors
#
#   interestGroup  joviality
# 0             H   0.001627
# 1             B   0.328087
# 2             A   0.393470
# 3             I   0.138063
# 4             H   0.857397

# %%
total_exp = result_df[(result_df.category != "Wage") & (result_df.category != "RentAdjustment")].groupby("participantId")["amount"].sum()
total_exp
# Out:
# participantId
# 0       18226.839829
# 1       21139.514857
# 2       18363.684618
# 3       19327.114335
# 4       33132.259641
#             ...
# 1006    19239.292195
# 1007    24756.701369
# 1008    14491.497800
# 1009    22273.255338
# 1010    19331.243416
# Name: amount, Length: 1011, dtype: float64

# %%
food_exp = result_df[result_df.category == "Food"].groupby("participantId")["amount"].sum()
food_exp
# Out:
# participantId
# 0       3868.580758
# 1       3912.751140
# 2       4265.218707
# 3       4189.696815
# 4       4017.282757
#            ...
# 1006    6559.485799
# 1007    6644.145592
# 1008    4306.678867
# 1009    7924.229957
# 1010    4284.186971
# Name: amount, Length: 1011, dtype: float64

# %%
engel_coeff = (food_exp / total_exp).rename("engels")
engel_coeff
# Out:
# participantId
# 0       0.212246
# 1       0.185092
# 2       0.232264
# 3       0.216778
# 4       0.121250
#           ...
# 1006    0.340942
# 1007    0.268378
# 1008    0.297187
# 1009    0.355773
# 1010    0.221620
# Name: engels, Length: 1011, dtype: float64

# %%
part_df_augmented = part_df.merge(engel_coeff, on="participantId")
part_df_augmented["haveKids"] = part_df_augmented["haveKids"].map({True: "TRUE", False: "FALSE"})
part_df_augmented
# Out:
#       participantId  householdSize haveKids  age       educationLevel  \
# 0                 0              3     TRUE   36  HighSchoolOrCollege
# 1                 1              3     TRUE   25  HighSchoolOrCollege
# 2                 2              3     TRUE   35  HighSchoolOrCollege
# 3                 3              3     TRUE   21  HighSchoolOrCollege
# 4                 4              3     TRUE   43            Bachelors
# ...             ...            ...      ...  ...                  ...
# 1006           1006              1    FALSE   19  HighSchoolOrCollege
# 1007           1007              1    FALSE   40  HighSchoolOrCollege
# 1008           1008              1    FALSE   23             Graduate
# 1009           1009              1    FALSE   39                  Low
# 1010           1010              1    FALSE   52  HighSchoolOrCollege
#
#      interestGroup  joviality    engels
# 0                H   0.001627  0.212246
# 1                B   0.328087  0.185092
# 2                A   0.393470  0.232264
# 3                I   0.138063  0.216778
# 4                H   0.857397  0.121250
# ...            ...        ...       ...
# 1006             J   0.639268  0.340942
# 1007             B   0.934348  0.268378
# 1008             C   0.163721  0.297187
# 1009             B   0.828330  0.355773
# 1010             D   0.175388  0.221620
#
# [1011 rows x 8 columns]

# %%
custom_to_csv(part_df_augmented, "ParticipantsAugmented.csv")

# %% [markdown]
# <hr/>

# %%
participants = pd.read_csv("ParticipantsAugmented.csv")
participants
# Out:
#       participantId  householdSize  haveKids  age       educationLevel  \
# 0                 0              3      True   36  HighSchoolOrCollege
# 1                 1              3      True   25  HighSchoolOrCollege
# 2                 2              3      True   35  HighSchoolOrCollege
# 3                 3              3      True   21  HighSchoolOrCollege
# 4                 4              3      True   43            Bachelors
# ...             ...            ...       ...  ...                  ...
# 1006           1006              1     False   19  HighSchoolOrCollege
# 1007           1007              1     False   40  HighSchoolOrCollege
# 1008           1008              1     False   23             Graduate
# 1009           1009              1     False   39                  Low
# 1010           1010              1     False   52  HighSchoolOrCollege
#
#      interestGroup  joviality    engels
# 0                H   0.001627  0.212246
# 1                B   0.328087  0.185092
# 2                A   0.393470  0.232264
# 3                I   0.138063  0.216778
# 4                H   0.857397  0.121250
# ...            ...        ...       ...
# 1006             J   0.639268  0.340942
# 1007             B   0.934348  0.268378
# 1008             C   0.163721  0.297187
# 1009             B   0.828330  0.355773
# 1010             D   0.175388  0.221620
#
# [1011 rows x 8 columns]

# %%
homes = pd.read_csv("homes.csv")[["participantId", "apartments"]]
homes
# Out:
#       participantId          apartments
# 0                 0                 926
# 1                 1                 928
# 2                 2                 291
# 3                 3                1243
# 4                 4  194,210,29,375,136
# ...             ...                 ...
# 1006           1006                1633
# 1007           1007                1620
# 1008           1008                 525
# 1009           1009                 663
# 1010           1010                 597
#
# [1011 rows x 2 columns]

# %%
def split_apartments(x):
    if type(x) == float:
        return pd.NA # NaN are now pandas.NA
    else:
        return int(x.split(",")[-1])

homes["apartmentId"] = homes["apartments"].apply(split_apartments)
homes.drop("apartments", axis=1, inplace=True)
homes
# Out:
#       participantId apartmentId
# 0                 0         926
# 1                 1         928
# 2                 2         291
# 3                 3        1243
# 4                 4         136
# ...             ...         ...
# 1006           1006        1633
# 1007           1007        1620
# 1008           1008         525
# 1009           1009         663
# 1010           1010         597
#
# [1011 rows x 2 columns]

# %%
apartments = pd.read_csv("ApartmentsCoord.csv")
apartments
# Out:
#       apartmentId  rentalCost  maxOccupancy  numberOfRooms    locationX  \
# 0               1      768.16             2              4  1077.697944
# 1               2     1014.55             2              1  -185.929284
# 2               3     1057.39             4              3  2123.014186
# 3               4     1259.10             4              3  2103.630178
# 4               5      411.50             1              4     7.058974
# ...           ...         ...           ...            ...          ...
# 1512         1729      703.80             2              4 -4097.077997
# 1513         1730     1104.62             4              2 -4334.244917
# 1514         1731      890.69             4              1 -3330.585557
# 1515         1732      703.80             2              3 -4151.807872
# 1516         1733      607.99             2              3 -4584.719946
#
#         locationY  buildingId
# 0      648.442716         340
# 1     1520.327098         752
# 2     5126.753457         639
# 3     4266.932930         397
# 4       79.961637         628
# ...           ...         ...
# 1512  7409.520667         182
# 1513  7164.441147         613
# 1514  7588.646019         513
# 1515  7409.520667         182
# 1516  4739.946540         913
#
# [1517 rows x 7 columns]

# %%
homesJoined = homes.merge(apartments, on="apartmentId", how="left")
homesJoined.drop(["rentalCost", "maxOccupancy", "numberOfRooms", "buildingId"], axis=1, inplace=True)
homesJoined
# Out:
#     participantId apartmentId    locationX    locationY
# 0               0         926 -2721.353174  6862.861219
# 1               1         928 -1531.132885  5597.244220
# 2               2         291 -1352.967752  2095.779440
# 3               3        1243 -1550.046162  5606.726709
# 4               4         136  1488.478248  3490.893224
# 5               5         243 -1511.444069  1994.482112
# 6               6         183  1789.415305  3245.310488
# 7               7          97 -1025.463021  1571.165821
# 8               8         321   611.334660  2266.011784
# 9               9         355 -2025.813803  2039.399099
# 10             10          91  1816.354964  5215.958138
# 11             11        1582 -4580.138686  7008.662374
# 12             12        1198  -511.596082  6362.843896
# 13             13         141   585.791812  3538.798389
# 14             14          66  1603.441866  4025.563331
# 15             15         930 -1662.149749  5616.284374
# 16             16         101  1831.089370  5326.192433
# 17             17        1003 -1704.771328  5630.225698
# 18             18         482 -1062.381230  3002.121591
# 19             19         276  1792.288741  3445.633257
# 20             20         301 -1435.412888  2057.431875
# 21             21         169  1409.399529  3410.171268
# 22             22          88  1621.751664  4457.745004
# 23             23         532 -1108.701325  3076.576967
# 24             24         309 -1530.703986  2057.431875
# 25             25         273 -1702.105728  2048.271561
# 26             26         371 -1627.322918  2048.271561
# 27             27        1239 -1551.334365  5650.818930
# 28             28        1254 -1551.334365  5676.174238
# 29             29         344  2217.516894  4848.952197
# 30             30         284   678.080928  2936.817540
# 31             31         810 -1190.949104  2889.114136
# 32             32        1146  -625.572481  6284.072403
# 33             33        1397 -4588.788595  7076.240408
# 34             34          35  2050.180926  4335.080359
# 35             35         215  1491.796033  3427.969569
# 36             36         111 -1851.781052  1845.275157
# 37             37        1080 -2401.058310  6214.165375
# 38             38        1216 -1845.105423  6223.628607
# 39             39         188  1259.755032  4768.654035
# 40             40         977     4.502698  5359.332759
# 41             41         245  1404.796399  3346.433605
# 42             42        1471 -4411.712653  4644.449348
# 43             43         934  -615.361040  6219.202533
# 44             44        <NA>          NaN          NaN
# 45             45         955 -2495.139054  6791.116923
# 46             46         985  -574.854541  6184.855099
# 47             47          58 -1473.175632   954.922679
# 48             48         115  1217.507751  3514.169785
# 49             49        1247 -1670.287981  6254.208539

# %%
participantsJoined = participants.merge(homesJoined, on="participantId", how="left")
participantsJoined
# Out:
#       participantId  householdSize  haveKids  age       educationLevel  \
# 0                 0              3      True   36  HighSchoolOrCollege
# 1                 1              3      True   25  HighSchoolOrCollege
# 2                 2              3      True   35  HighSchoolOrCollege
# 3                 3              3      True   21  HighSchoolOrCollege
# 4                 4              3      True   43            Bachelors
# ...             ...            ...       ...  ...                  ...
# 1006           1006              1     False   19  HighSchoolOrCollege
# 1007           1007              1     False   40  HighSchoolOrCollege
# 1008           1008              1     False   23             Graduate
# 1009           1009              1     False   39                  Low
# 1010           1010              1     False   52  HighSchoolOrCollege
#
#      interestGroup  joviality    engels apartmentId    locationX    locationY
# 0                H   0.001627  0.212246         926 -2721.353174  6862.861219
# 1                B   0.328087  0.185092         928 -1531.132885  5597.244220
# 2                A   0.393470  0.232264         291 -1352.967752  2095.779440
# 3                I   0.138063  0.216778        1243 -1550.046162  5606.726709
# 4                H   0.857397  0.121250         136  1488.478248  3490.893224
# ...            ...        ...       ...         ...          ...          ...
# 1006             J   0.639268  0.340942        1633 -4227.336286  5302.398117
# 1007             B   0.934348  0.268378        1620 -3969.050409  6563.139153
# 1008             C   0.163721  0.297187         525 -2158.723147  2525.141681
# 1009             B   0.828330  0.355773         663 -2366.812535  4880.767220
# 1010             D   0.175388  0.221620         597 -2114.647404  2602.884684
#
# [1011 rows x 11 columns]

# %%
custom_to_csv(participantsJoined, "ParticipantsAugmented.csv")

# %% [markdown]
# <hr/>

# %%
aggregatedFinancial = pd.read_csv("AggregatedFinancialJournal.csv")
expensesCategories = aggregatedFinancial["category"].unique()
print(expensesCategories)
aggregatedFinancial
# Out:
# ['Education' 'Food' 'Recreation' 'Shelter' 'Wage' 'RentAdjustment']
#       participantId    category         amount
# 0                 0   Education     608.086073
# 1                 0        Food    3868.580758
# 2                 0  Recreation    4870.355051
# 3                 0     Shelter    8879.817947
# 4                 0        Wage  134904.668457
# ...             ...         ...            ...
# 4137           1009        Wage   28045.271601
# 4138           1010        Food    4284.186971
# 4139           1010  Recreation    7601.419125
# 4140           1010     Shelter    7445.637320
# 4141           1010        Wage   33381.068889
#
# [4142 rows x 3 columns]

# %%
participants = pd.read_csv("ParticipantsAugmented.csv")
for cat in expensesCategories:
    participants[cat] = 0.0

def aptIdtoInt(x):
    if pd.isna(x):
        return pd.NA
    else:
        return int(x)

participants["apartmentId"] = participants["apartmentId"].apply(aptIdtoInt)

# %%
def update_expenses(row):
    participants.loc[participants["participantId"] == row["participantId"], [row["category"]]] += row["amount"]

aggregatedFinancial.apply(update_expenses, axis=1)
participants
# Out:
#       participantId  householdSize  haveKids  age       educationLevel  \
# 0                 0              3      True   36  HighSchoolOrCollege
# 1                 1              3      True   25  HighSchoolOrCollege
# 2                 2              3      True   35  HighSchoolOrCollege
# 3                 3              3      True   21  HighSchoolOrCollege
# 4                 4              3      True   43            Bachelors
# ...             ...            ...       ...  ...                  ...
# 1006           1006              1     False   19  HighSchoolOrCollege
# 1007           1007              1     False   40  HighSchoolOrCollege
# 1008           1008              1     False   23             Graduate
# 1009           1009              1     False   39                  Low
# 1010           1010              1     False   52  HighSchoolOrCollege
#
#      interestGroup  joviality    engels apartmentId    locationX    locationY  \
# 0                H   0.001627  0.212246         926 -2721.353174  6862.861219
# 1                B   0.328087  0.185092         928 -1531.132885  5597.244220
# 2                A   0.393470  0.232264         291 -1352.967752  2095.779440
# 3                I   0.138063  0.216778        1243 -1550.046162  5606.726709
# 4                H   0.857397  0.121250         136  1488.478248  3490.893224
# ...            ...        ...       ...         ...          ...          ...
# 1006             J   0.639268  0.340942        1633 -4227.336286  5302.398117
# 1007             B   0.934348  0.268378        1620 -3969.050409  6563.139153
# 1008             C   0.163721  0.297187         525 -2158.723147  2525.141681
# 1009             B   0.828330  0.355773         663 -2366.812535  4880.767220
# 1010             D   0.175388  0.221620         597 -2114.647404  2602.884684
#
#        Education         Food    Recreation       Shelter           Wage  \
# 0     608.086073  3868.580758   4870.355051   8879.817947  134904.668457
# 1     608.086073  3912.751140   7738.859696   8879.817947  118421.022133
# 2     204.999120  4265.218707   4988.619955   8904.846836  104429.003555
# 3     608.086073  4189.696815   5649.513500   8879.817947  100943.911799
# 4     204.999120  4017.282757   7492.829448  21417.148316  130266.886107
# ...          ...          ...           ...           ...            ...
# 1006    0.000000  6559.485799   5124.502128   7555.304268   28160.145453
# 1007    0.000000  6644.145592  10008.671691   8103.884086   28134.000854
# 1008    0.000000  4306.678867   2739.181613   7445.637320   56506.356576
# 1009    0.000000  7924.229957   6903.388062   7445.637320   28045.271601
# 1010    0.000000  4284.186971   7601.419125   7445.637320   33381.068889
#
#       RentAdjustment
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4        4809.283427
# ...              ...
# 1006        0.000000
# 1007        0.000000
# 1008        0.000000
# 1009        0.000000
# 1010        0.000000
#
# [1011 rows x 17 columns]

# %%
custom_to_csv(participants, "ParticipantsAugmented.csv")

# %% [markdown]
# <hr/>

# %%
participants = pd.read_csv("ParticipantsAugmented.csv")
participants["apartmentId"] = participants["apartmentId"].apply(aptIdtoInt)

# remove all rows with a NaN value
participantsDropped = participants.dropna()
participantsDropped
# Out:
#       participantId  householdSize  haveKids  age       educationLevel  \
# 0                 0              3      True   36  HighSchoolOrCollege
# 1                 1              3      True   25  HighSchoolOrCollege
# 2                 2              3      True   35  HighSchoolOrCollege
# 3                 3              3      True   21  HighSchoolOrCollege
# 4                 4              3      True   43            Bachelors
# ...             ...            ...       ...  ...                  ...
# 1006           1006              1     False   19  HighSchoolOrCollege
# 1007           1007              1     False   40  HighSchoolOrCollege
# 1008           1008              1     False   23             Graduate
# 1009           1009              1     False   39                  Low
# 1010           1010              1     False   52  HighSchoolOrCollege
#
#      interestGroup  joviality    engels apartmentId    locationX    locationY  \
# 0                H   0.001627  0.212246         926 -2721.353174  6862.861219
# 1                B   0.328087  0.185092         928 -1531.132885  5597.244220
# 2                A   0.393470  0.232264         291 -1352.967752  2095.779440
# 3                I   0.138063  0.216778        1243 -1550.046162  5606.726709
# 4                H   0.857397  0.121250         136  1488.478248  3490.893224
# ...            ...        ...       ...         ...          ...          ...
# 1006             J   0.639268  0.340942        1633 -4227.336286  5302.398117
# 1007             B   0.934348  0.268378        1620 -3969.050409  6563.139153
# 1008             C   0.163721  0.297187         525 -2158.723147  2525.141681
# 1009             B   0.828330  0.355773         663 -2366.812535  4880.767220
# 1010             D   0.175388  0.221620         597 -2114.647404  2602.884684
#
#        Education         Food    Recreation       Shelter           Wage  \
# 0     608.086073  3868.580758   4870.355051   8879.817947  134904.668457
# 1     608.086073  3912.751140   7738.859696   8879.817947  118421.022133
# 2     204.999120  4265.218707   4988.619955   8904.846836  104429.003555
# 3     608.086073  4189.696815   5649.513500   8879.817947  100943.911799
# 4     204.999120  4017.282757   7492.829448  21417.148316  130266.886107
# ...          ...          ...           ...           ...            ...
# 1006    0.000000  6559.485799   5124.502128   7555.304268   28160.145453
# 1007    0.000000  6644.145592  10008.671691   8103.884086   28134.000854
# 1008    0.000000  4306.678867   2739.181613   7445.637320   56506.356576
# 1009    0.000000  7924.229957   6903.388062   7445.637320   28045.271601
# 1010    0.000000  4284.186971   7601.419125   7445.637320   33381.068889
#
#       RentAdjustment
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4        4809.283427
# ...              ...
# 1006        0.000000
# 1007        0.000000
# 1008        0.000000
# 1009        0.000000
# 1010        0.000000
#
# [880 rows x 17 columns]

# %%
custom_to_csv(participantsDropped, "ParticipantsAugmented.csv")

# %% [markdown]
# <hr/>
#
# <h1>Activities</h1>

# %%
# load pubs and restaurants
pubs = pd.read_csv("PubLocation.csv")
pubs["venueType"] = "Pub"
pubs.rename(columns={"pubId": "venueId"}, inplace=True)
pubs.rename(columns={"hourlyCost": "cost"}, inplace=True)
restaurants = pd.read_csv("RestaurantLocation.csv")
restaurants["venueType"] = "Restaurant"
restaurants.rename(columns={"restaurantId": "venueId"}, inplace=True)
restaurants.rename(columns={"foodCost": "cost"}, inplace=True)

# merge pubs and restaurants
activities = pd.concat([pubs, restaurants]).reset_index(drop=True)
activities.drop(["buildingId"], axis=1, inplace=True)
activities
# Out:
#     venueId       cost  maxOccupancy    locationX    locationY   venueType
# 0       442   8.281103            64   964.438023  3991.603474         Pub
# 1       443   6.417435            64  1809.880173  4339.172426         Pub
# 2       444  12.581806            84   770.427904   932.585200         Pub
# 3       892  11.642905            96 -1524.957321  3815.271490         Pub
# 4       893  14.840473            79 -1608.766411  3886.492478         Pub
# 5       894  12.311210            72 -1702.537816  3865.477091         Pub
# 6      1342  14.140037            77  -260.457470  5026.150804         Pub
# 7      1343  10.524972            67  -501.426761  3551.572639         Pub
# 8      1344  10.415293            60  -225.920987  3878.053698         Pub
# 9      1798  11.545351            64 -3209.738139  6487.657688         Pub
# 10     1799   7.487082            73 -3903.194076  5967.836984         Pub
# 11     1800  10.206845            62 -3796.119851  6367.922073         Pub
# 12      445   5.150000            71   631.513072  2001.477203  Restaurant
# 13      446   4.170000            82   413.840001  1194.128694  Restaurant
# 14      447   5.870000           119   497.996794  1624.515148  Restaurant
# 15      448   4.070000            98   698.241116  4392.416668  Restaurant
# 16      449   5.110000            53  1407.710770  4010.457482  Restaurant
# 17      895   4.440000           103 -1623.074059  3872.030011  Restaurant
# 18      896   5.860000           107 -2126.172394  4285.182228  Restaurant
# 19      897   5.760000           104 -1989.635264  3368.764838  Restaurant
# 20      898   4.220000           115 -1771.452217  4343.580177  Restaurant
# 21      899   5.650000            85  -820.929028  4497.243309  Restaurant
# 22     1345   4.700000            72 -1176.801330  5846.647124  Restaurant
# 23     1346   5.850000            74 -3529.558387  4809.641128  Restaurant
# 24     1347   4.410000            87 -1221.405110  4941.003384  Restaurant
# 25     1348   4.230000            57  -508.126910  6307.584421  Restaurant
# 26     1349   4.770000           104 -1176.698906  4726.117600  Restaurant
# 27     1801   5.510000            64 -3136.127896  6671.917462  Restaurant
# 28     1802   5.080000            72 -4002.933531  6671.996711  Restaurant
# 29     1803   4.350000            94 -3182.885941  7167.608699  Restaurant
# 30     1804   5.920000            48 -4131.414092  7236.525633  Restaurant
# 31     1805   5.590000            85 -3927.910240  5494.639627  Restaurant

# %%
visitsLog = pd.read_csv("VisitsLog.csv")
# create dataframe with venueId and total count of visits
visitsLog = visitsLog.groupby("venueId")["count"].sum().reset_index().rename(columns={"count": "totalVisits"})
activities = activities.merge(visitsLog, on="venueId")
activities
# Out:
#     venueId       cost  maxOccupancy    locationX    locationY   venueType  \
# 0       442   8.281103            64   964.438023  3991.603474         Pub
# 1       443   6.417435            64  1809.880173  4339.172426         Pub
# 2       444  12.581806            84   770.427904   932.585200         Pub
# 3       892  11.642905            96 -1524.957321  3815.271490         Pub
# 4       893  14.840473            79 -1608.766411  3886.492478         Pub
# 5       894  12.311210            72 -1702.537816  3865.477091         Pub
# 6      1342  14.140037            77  -260.457470  5026.150804         Pub
# 7      1343  10.524972            67  -501.426761  3551.572639         Pub
# 8      1344  10.415293            60  -225.920987  3878.053698         Pub
# 9      1798  11.545351            64 -3209.738139  6487.657688         Pub
# 10     1799   7.487082            73 -3903.194076  5967.836984         Pub
# 11     1800  10.206845            62 -3796.119851  6367.922073         Pub
# 12      445   5.150000            71   631.513072  2001.477203  Restaurant
# 13      446   4.170000            82   413.840001  1194.128694  Restaurant
# 14      447   5.870000           119   497.996794  1624.515148  Restaurant
# 15      448   4.070000            98   698.241116  4392.416668  Restaurant
# 16      449   5.110000            53  1407.710770  4010.457482  Restaurant
# 17      895   4.440000           103 -1623.074059  3872.030011  Restaurant
# 18      896   5.860000           107 -2126.172394  4285.182228  Restaurant
# 19      897   5.760000           104 -1989.635264  3368.764838  Restaurant
# 20      898   4.220000           115 -1771.452217  4343.580177  Restaurant
# 21      899   5.650000            85  -820.929028  4497.243309  Restaurant
# 22     1345   4.700000            72 -1176.801330  5846.647124  Restaurant
# 23     1346   5.850000            74 -3529.558387  4809.641128  Restaurant
# 24     1347   4.410000            87 -1221.405110  4941.003384  Restaurant
# 25     1348   4.230000            57  -508.126910  6307.584421  Restaurant
# 26     1349   4.770000           104 -1176.698906  4726.117600  Restaurant
# 27     1801   5.510000            64 -3136.127896  6671.917462  Restaurant
# 28     1802   5.080000            72 -4002.933531  6671.996711  Restaurant
# 29     1803   4.350000            94 -3182.885941  7167.608699  Restaurant
# 30     1804   5.920000            48 -4131.414092  7236.525633  Restaurant
# 31     1805   5.590000            85 -3927.910240  5494.639627  Restaurant
#
#     totalVisits
# 0         21703
# 1         19807
# 2         17592
# 3         23603
# 4         25255
# 5         20253
# 6         50400
# 7         31162
# 8         54174
# 9         31212
# 10        28589
# 11        31628
# 12         8354
# 13        17859
# 14        34270
# 15        33067
# 16        41639
# 17        30287
# 18        20755
# 19        31155
# 20        12778
# 21        28839
# 22        26115
# 23         6318
# 24         9444
# 25         9587
# 26         5063
# 27        48053
# 28        15954
# 29        12025
# 30        15571
# 31        38977

# %%
# Load the CSV files
checkin_df = pd.read_csv("../data/Datasets/Journals/CheckinJournal.csv")
financial_df = pd.read_csv("../data/Datasets/Journals/FinancialJournal.csv")
dropped_out = pd.read_csv("DroppedOut.csv")

# Filter CheckIns of dropped out participants
checkin_df = checkin_df[~checkin_df['participantId'].isin(dropped_out["participantId"])]
# Filter Financial Transactions about Food or Recreation
financial_df = financial_df[(financial_df['category'] == 'Food') | (financial_df['category'] == 'Recreation')]
financial_df = financial_df[~financial_df['participantId'].isin(dropped_out["participantId"])]
financial_df["amount"] = financial_df["amount"].abs()

# Convert timestamp columns to datetime dtype
checkin_df['timestamp'] = pd.to_datetime(checkin_df['timestamp'])
financial_df['timestamp'] = pd.to_datetime(financial_df['timestamp'])

# Merge FinancialJournal with CheckInJournal based on participantId
merged_df = pd.merge_asof(financial_df.sort_values('timestamp'), checkin_df.sort_values('timestamp'), 
                          by='participantId', on='timestamp', direction='backward')

# discard rows with NaN values
merged_df = merged_df.dropna()
merged_df = merged_df[(merged_df['venueType'] == 'Pub') | (merged_df['venueType'] == 'Restaurant')]

# drop columns
merged_df = merged_df.drop(columns=["participantId", "category"])
merged_df["venueId"] = merged_df["venueId"].astype(int)

# convert timestamps to only year and month
merged_df['timestamp'] = merged_df['timestamp'].dt.to_period('M')
merged_df
# Out:
# /tmp/ipykernel_152761/401114438.py:30: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   merged_df['timestamp'] = merged_df['timestamp'].dt.to_period('M')
#         timestamp     amount  venueId   venueType
# 16        2022-03   1.025934      894         Pub
# 50        2022-03   4.438301      895  Restaurant
# 60        2022-03   4.233449     1348  Restaurant
# 110       2022-03  14.840473      893         Pub
# 121       2022-03   4.103737      894         Pub
# ...           ...        ...      ...         ...
# 1327958   2023-05   2.760368      442         Pub
# 1327959   2023-05  22.566468     1344         Pub
# 1327960   2023-05  20.204365     1798         Pub
# 1327961   2023-05  11.642905      892         Pub
# 1327962   2023-05  25.977040     1798         Pub
#
# [827924 rows x 4 columns]

# %%
# group each venue and sum its monthly earnings
monthly_earnings = merged_df.groupby(['venueId', 'venueType', 'timestamp']).agg({'amount': 'sum'}).reset_index()
custom_to_csv(monthly_earnings, "EarningsLog.csv")
monthly_earnings
# Out:
#      venueId   venueType timestamp        amount
# 0        442         Pub   2022-03  35083.583269
# 1        442         Pub   2022-04  19956.078227
# 2        442         Pub   2022-05  16410.385927
# 3        442         Pub   2022-06  15980.458659
# 4        442         Pub   2022-07  17177.768145
# ..       ...         ...       ...           ...
# 475     1805  Restaurant   2023-01  14957.194914
# 476     1805  Restaurant   2023-02  13491.680678
# 477     1805  Restaurant   2023-03  15315.183124
# 478     1805  Restaurant   2023-04  14727.858716
# 479     1805  Restaurant   2023-05  11556.306915
#
# [480 rows x 4 columns]

# %%
# group each venue and sum its monthly earnings to achieve total earnings
total_earnings = monthly_earnings.groupby(['venueId', 'venueType']).agg({'amount': 'sum'}).reset_index() \
            .rename(columns={"amount": "totalEarnings"}).drop(columns=["venueType"])

# merge total earnings with activities
activities = activities.merge(total_earnings, on="venueId")
# Out:
#     venueId         amount
# 0       442  262603.439797
# 1       443  205745.117753
# 2       444  269969.914434
# 3       445   43007.279576
# 4       446   74531.767474
# 5       447  201316.682435
# 6       448  134593.913948
# 7       449  212909.573308
# 8       892  376873.078889
# 9       893  479653.969666
# 10      894  328433.331754
# 11      895  134422.817010
# 12      896  121597.811786
# 13      897  179460.274790
# 14      898   53876.229826
# 15      899  162887.752060
# 16     1342  835535.936918
# 17     1343  463349.631936
# 18     1344  745840.010679
# 19     1345  122646.841499
# 20     1346   36949.911271
# 21     1347   41693.289417
# 22     1348   40586.080242
# 23     1349   24165.226317
# 24     1798  485232.831204
# 25     1799  328247.380824
# 26     1800  453308.973372
# 27     1801  264747.952127
# 28     1802   81090.418772
# 29     1803   52336.344023
# 30     1804   92103.006291
# 31     1805  218020.413670
